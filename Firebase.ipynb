# %% [markdown]
# <a href="https://colab.research.google.com/github/jddiep/TLG_Project1/blob/main/Firebase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase-admin

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd

cred = credentials.Certificate("/content/names-key.json")

firebase_admin.initialize_app(cred)

# %%
db = firestore.client()
doc_ref = db.collection(u'index')
# Import data
df = pd.read_csv('/content/demo_names_dataset.csv')
tmp = df.to_dict(orient='records')
list(map(lambda x: doc_ref.add(x), tmp))
# Out:
# [(DatetimeWithNanoseconds(2023, 11, 22, 21, 18, 0, 316635, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x7b06586cbee0>),
#  (DatetimeWithNanoseconds(2023, 11, 22, 21, 18, 0, 436993, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x7b06586cb910>),
#  (DatetimeWithNanoseconds(2023, 11, 22, 21, 18, 0, 539686, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x7b06586caa70>),
#  (DatetimeWithNanoseconds(2023, 11, 22, 21, 18, 0, 637999, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x7b06586c9e70>),
#  (DatetimeWithNanoseconds(2023, 11, 22, 21, 18, 0, 737653, tzinfo=datetime.timezone.utc),
#   <google.cloud.firestore_v1.document.DocumentReference at 0x7b06586cb9a0>),
#  (DatetimeWithNanoseconds(2023, 11, 22, 21, 18, 0, 923178, tzinfo=datetime.timezone.utc),
# ...
