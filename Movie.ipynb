# %% [markdown]
# <a href="https://colab.research.google.com/github/jddiep/TLG_Project1/blob/main/Movie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 52.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 90.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# ...

# %%
# %%writefile movie.py
import pandas as pd
import streamlit as st

names_link='/content/moviescsv.csv'
names_data=pd.read_csv(names_link)
data_movies = pd.read_csv(names_link)

sidebar = st.sidebar

sidebar.title("Movie App")
sidebar.write("Listado de películas")

sidebar.header("Data Description")
selected_class = sidebar.radio("Select Class",data_movies['rating'].unique())
sidebar.write("Selected Class:", selected_class)
sidebar.markdown("___")

st.title("Informacion sobre el Conjunto de Datos")
st.header("Información sobre Películas")

st.write("""Este es un ejemplo de una app para predecir
¡Esta app predice mis películas:
         """)

sidebar.header("Dataset")
agree = sidebar.checkbox("Show DataSet Overview ? ")
if agree:
 st.dataframe(data_movies)

@st.cache_data
def load_data_byname(name):
  data_movies = pd.read_csv(names_link)
  filtered_data_bymoviename = data_movies[data_movies['name'].str.contains(name)]

  return filtered_data_bymoviename

myname = sidebar.text_input('Titulo de película :')
#st.write(myname.upper())
if (myname):
  data_load_state = st.text('Loading data...')
  filterbyname = load_data_byname(myname)
  count_row = filterbyname.shape[0]
  st.write(f"Total names : {count_row} " myname.upper())
  data_load_state.text("Done! (using st.cache)")

  st.dataframe(filterbyname)

#user_text = st.text_input(...)

#if user_text.lower() == 'flowers mansion':
#   pass
#elif user_text.lower() == 'something else':
#   do_something()
# Out:
# Overwriting movie.py

# %%
# !streamlit run movie.py & npx localtunnel --port 8501
# Out:
# [..................] | fetchMetadata: sill resolveWithNewModule localtunnel@2.0
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.150.215.135:8501
#
# npx: installed 22 in 2.733s
# your url is: https://fair-tables-send.loca.lt
#   Stopping...
# ^C
